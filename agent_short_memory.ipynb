# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver
from langchain.messages import HumanMessage
from dotenv import load_dotenv
from pprint import pprint

load_dotenv()
# Out:
# True

# %%
agent = create_agent(
    model="anthropic:claude-haiku-4-5",
    checkpointer=InMemorySaver(),
)

# %%
user_message = HumanMessage(content="Hello my name is Subham and my favourite colors is black.")

# %%
config = {"configurable": {"thread_id": "1"}}

# %%
response = agent.invoke(
    {
        "messages": [user_message],
    },
    config=config,  # type: ignore
)

# %%
pprint(response["messages"][-1].content)
# Out:
# ("Hello Subham! Nice to meet you. Black is a great choice—it's a classic color "
#  "that's versatile, elegant, and powerful. It works well in fashion, design, "
#  'and many other contexts.\n'
#  '\n'
#  'Is there something I can help you with today?')

# %%
question = HumanMessage(content="What is my name and favourite color?")

# %%
new_response = agent.invoke(
    {
        "messages": [question],
    },
    config=config,  # type: ignore
)

# %%
pprint(new_response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Subham and my favourite colors is black.', additional_kwargs={}, response_metadata={}, id='329e6b01-c2b4-446e-afac-718096fb2bd0'),
#               AIMessage(content="Hello Subham! Nice to meet you. Black is a great choice—it's a classic color that's versatile, elegant, and powerful. It works well in fashion, design, and many other contexts.\n\nIs there something I can help you with today?", additional_kwargs={}, response_metadata={'id': 'msg_011CekXCYzDFG5VdkRqZMQLh', 'container': None, 'model': 'claude-haiku-4-5-20251001', 'stop_details': None, 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'inference_geo': 'not_available', 'input_tokens': 21, 'output_tokens': 58, 'output_tokens_details': None, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-haiku-4-5-20251001', 'model_provider': 'anthropic'}, id='lc_run--01a07229-ff48-7bf2-8448-a6989c9fce33-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 21, 'output_tokens': 58, 'total_tokens': 79, 'input_token_details': {'cache_creation': 0, 'cache_read': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}}),
#               HumanMessage(content='What is my name and favourite color?', additional_kwargs={}, response_metadata={}, id='8169c975-20be-454c-b221-845e5fa8b128'),
#               AIMessage(content='Your name is **Subham** and your favourite color is **black**.', additional_kwargs={}, response_metadata={'id': 'msg_011CekXDHLA17pviu1y7RBUN', 'container': None, 'model': 'claude-haiku-4-5-20251001', 'stop_details': None, 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'inference_geo': 'not_available', 'input_tokens': 90, 'output_tokens': 19, 'output_tokens_details': None, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-haiku-4-5-20251001', 'model_provider': 'anthropic'}, id='lc_run--01a0722a-268e-78c2-a279-cda34204a350-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 90, 'output_tokens': 19, 'total_tokens': 109, 'input_token_details': {'cache_read': 0, 'cache_creation': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}})]}

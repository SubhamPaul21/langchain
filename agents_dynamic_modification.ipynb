# %%
from IPython.display import Image

# %%
Image(filename='D:\\Artificial Intelligence\\langchain\\screenshots\\dynamic_agents.png')

# %%
Image(filename='D:\\Artificial Intelligence\\langchain\\screenshots\\dynamic_agents_code.png')

# %%
Image(filename='D:\\Artificial Intelligence\\langchain\\screenshots\\dynamic_agents_modify_tools_based_on_role.png')

# %%
Image(filename='D:\\Artificial Intelligence\\langchain\\screenshots\\dynamic_agents_modify_model.png')

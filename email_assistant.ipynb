# %%
from IPython.display import Image

# %%
Image(filename='D:\\Artificial Intelligence\\langchain\\screenshots\\email_assistant_context_and_state.png')

# %%
Image(filename='D:\\Artificial Intelligence\\langchain\\screenshots\\email_assistant_tools_1.png')

# %%
Image(filename='D:\\Artificial Intelligence\\langchain\\screenshots\\email_assistant_tools_2.png')

# %%
Image(filename='D:\\Artificial Intelligence\\langchain\\screenshots\\email_assistant_wrap_model_call.png')

# %%
Image(filename='D:\\Artificial Intelligence\\langchain\\screenshots\\email_assistant_dynamic_prompt.png')

# %%
Image(filename='D:\\Artificial Intelligence\\langchain\\screenshots\\email_assistant_main_agent.png')

# %%
Image(filename='D:\\Artificial Intelligence\\langchain\\screenshots\\.png')

# %%
Image(filename='D:\\Artificial Intelligence\\langchain\\screenshots\\.png')

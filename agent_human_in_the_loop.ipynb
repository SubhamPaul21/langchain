# %%
from IPython.display import Image

# %%
Image(filename='D:\\Artificial Intelligence\\langchain\\screenshots\\human_in_the_loop_middleware.png')

# %%
Image(filename='D:\\Artificial Intelligence\\langchain\\screenshots\\human_in_the_loop_middleware_accept.png')

# %%
Image(filename='D:\\Artificial Intelligence\\langchain\\screenshots\\human_in_the_loop_middleware_reject.png')

# %%
Image(filename='D:\\Artificial Intelligence\\langchain\\screenshots\\human_in_the_loop_middleware_edit.png')

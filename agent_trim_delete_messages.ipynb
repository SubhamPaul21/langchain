# %% [markdown]
# ### Using middlewares such as before_agent, before_model or after_agent, after_model to execute functions at required places.

# %%
from IPython.display import Image
Image(filename='D:\\Artificial Intelligence\\langchain\\screenshots\\trim_messages_with_middlewares.png')

# %%
Image(filename='D:\\Artificial Intelligence\\langchain\\screenshots\\trim_messages_with_middlewares_code.png')
